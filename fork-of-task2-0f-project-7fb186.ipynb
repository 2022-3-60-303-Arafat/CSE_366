fficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))

# ---------- Auto-detect PlantVillage root ----------
BASE_DIR_CANDIDATES = [
    "/kaggle/input/plantdisease/PlantVillage",
    "/kaggle/input/plantdisease/color",
    "/kaggle/input/plantdisease",
    "/kaggle/input/plantvillage",
    "/kaggle/input/PlantVillage"
]
base_dir = None
for p in BASE_DIR_CANDIDATES:
    if os.path.exists(p):
        base_dir = p
        break
assert base_dir is not None, "Dataset not found. In Kaggle, Add Data → `emmarex/plantdisease`."

# Working directory where we write a clean split
work_root = "/kaggle/working/Tomato_Split"
os.makedirs(work_root, exist_ok=True)

# Reproducibility
random_seed = 1
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# ---------- Splits (meet requirement: Test in [0.20, 0.30]) ----------
TEST_FRACTION = 0.25
VAL_FRACTION_OF_TRAINVAL = 0.20
assert 0.20 <= TEST_FRACTION <= 0.30, "TEST_FRACTION must be between 0.20 and 0.30."

# Image/batch
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Training schedule (two-stage)
STAGE1_EPOCHS = 35   # feature extraction
STAGE2_EPOCHS = 40   # fine-tuning
UNFREEZE_FRACTION = 0.25  # unfreeze top 25% of base in stage 2

# Optim / LR policy
BASE_LR = 3e-4
MIN_LR = 1e-6
PATIENCE_ES = 3
PATIENCE_RLRP = 1

# Tomato classes (10 expected)
tomato_classes = [
     'Tomato_Bacterial_spot',
    'Tomato_Early_blight',
    'Tomato_Late_blight',
    'Tomato_Leaf_Mold',
    'Tomato_Septoria_leaf_spot',
    'Tomato_Spider_mites_Two_spotted_spider_mite',
    'Tomato__Target_Spot',
    'Tomato__Tomato_YellowLeaf__Curl_Virus',
    'Tomato__Tomato_mosaic_virus',
    'Tomato_healthy'



]

print("base_dir:", base_dir, "| work_root:", work_root)

# =========================
# Robust pretrained loader
# =========================
WEIGHTS_DIR_CANDIDATES = [
    "/kaggle/input/keras-application-weights",
    "/kaggle/input/keras-weights",
    "/kaggle/input/tf-imagenet-weights",
]

WEIGHT_FILENAMES = {
    "VGG16": "vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5",
    "ResNet50": "resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5",
    "EfficientNetB0": "efficientnetb0_notop.h5",  # common name used in many mirrors
}

def _find_local_weight_path(model_name):
    fname = WEIGHT_FILENAMES.get(model_name)
    if not fname:
        return None
    for d in WEIGHTS_DIR_CANDIDATES:
        p = os.path.join(d, fname)
        if os.path.exists(p):
            return p
    return None

def _try_imagenet_with_retries(base_fn, input_shape, n_retries=3, sleep_s=3):
    last_err = None
    for attempt in range(1, n_retries+1):
        try:
            base = base_fn(weights="imagenet", include_top=False, input_shape=input_shape)
            return base
        except Exception as e:
            last_err = e
            print(f"[retry {attempt}/{n_retries}] Failed to load ImageNet weights: {e}")
            time.sleep(sleep_s)
    raise last_err

def load_base_with_fallback(model_name, base_fn, input_shape):
    """
    Order:
      1) Try ImageNet with retries (internet path)
      2) Try local file (if attached)
      3) Fallback to random init (warning)
    Returns: (base_model, source_str)
    """
    # 1) Internet download (with retries)
    try:
        base = _try_imagenet_with_retries(base_fn, input_shape)
        print(f"[{model_name}] Using ImageNet weights (download/cache).")
        return base, "imagenet"
    except Exception as e:
        print(f"[{model_name}] WARN: ImageNet weights unavailable after retries: {e}")

    # 2) Local weights (optional dataset)
    local_path = _find_local_weight_path(model_name)
    if local_path is not None:
        try:
            base = base_fn(weights=local_path, include_top=False, input_shape=input_shape)
            print(f"[{model_name}] Using LOCAL weights: {local_path}")
            return base, "local"
        except Exception as e:
            print(f"[{model_name}] WARN: Local weights failed to load: {e}")

    # 3) Random init fallback
    base = base_fn(weights=None, include_top=False, input_shape=input_shape)
    print(f"[{model_name}] Using RANDOM initialization (no pretrained weights). "
          f"Tip: attach a weights dataset or keep Internet ON.")
    return base, "random"

# =========================
# Split builder (copy files)
# =========================
def prepare_splits(src_root, dest_root, classes, test_frac, val_frac_of_remaining, seed=123):
    random.seed(seed)
    for split in ['train','val','test']:
        for cls in classes:
            os.makedirs(os.path.join(dest_root, split, cls), exist_ok=True)

    for cls in classes:
        # locate class folder (some datasets nested)
        candidate = os.path.join(src_root, cls)
        found_dir = None
        if os.path.exists(candidate):
            found_dir = candidate
        else:
            for root, dirs, _ in os.walk(src_root):
                if os.path.basename(root) == cls:
                    found_dir = root
                    break

        if found_dir is None:
            print("⚠️ Missing folder, skipping:", cls)
            continue

        files = [f for f in os.listdir(found_dir) if f.lower().endswith(('.jpg','.jpeg','.png','.bmp','.tif','.tiff'))]
        random.shuffle(files)
        n = len(files)
        if n == 0:
            print("⚠️ No images for:", cls)
            continue

        n_test = int(n * test_frac)
        n_val = int((n - n_test) * val_frac_of_remaining)

        test_files = files[:n_test]
        val_files = files[n_test:n_test+n_val]
        train_files = files[n_test+n_val:]

        for f in train_files:
            shutil.copy(os.path.join(found_dir,f), os.path.join(dest_root,'train',cls,f))
        for f in val_files:
            shutil.copy(os.path.join(found_dir,f), os.path.join(dest_root,'val',cls,f))
        for f in test_files:
            shutil.copy(os.path.join(found_dir,f), os.path.join(dest_root,'test',cls,f))

        print(f"{cls}: total={n} -> train={len(train_files)}, val={len(val_files)}, test={len(test_files)}")

def clean_empty_and_hidden_dirs(root_dir):
    for root_dirpath, dirs, files in os.walk(root_dir):
        for d in dirs:
            dir_path = os.path.join(root_dirpath, d)
            if d.startswith('.') or 'checkpoint' in d.lower():
                shutil.rmtree(dir_path, ignore_errors=True)
            else:
                try:
                    if os.path.isdir(dir_path) and len(os.listdir(dir_path)) == 0:
                        os.rmdir(dir_path)
                except Exception:
                    pass

prepare_splits(base_dir, work_root, tomato_classes, TEST_FRACTION, VAL_FRACTION_OF_TRAINVAL, random_seed)
clean_empty_and_hidden_dirs(work_root)

for s in ['train','val','test']:
    total = 0
    for c in tomato_classes:
        p = os.path.join(work_root, s, c)
        if os.path.exists(p):
            total += len(os.listdir(p))
    print(f"{s}: {total} images")

# =========================
# Generators
# =========================
clean_empty_and_hidden_dirs(work_root)

train_aug = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.15,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)
test_val_gen = ImageDataGenerator(rescale=1./255)

train_gen = train_aug.flow_from_directory(
    os.path.join(work_root,'train'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=random_seed
)
val_gen = test_val_gen.flow_from_directory(
    os.path.join(work_root,'val'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=random_seed
)
test_gen = test_val_gen.flow_from_directory(
    os.path.join(work_root,'test'),
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=random_seed
)

num_classes = train_gen.num_classes
class_names = list(train_gen.class_indices.keys())
print("Classes detected:", class_names)
print("Counts -> Train:", train_gen.samples, "Val:", val_gen.samples, "Test:", test_gen.samples)

# =========================
# Model head & callbacks
# =========================
def build_classifier(base_model, lr=BASE_LR, head_units=256):
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dropout(0.4),
        Dense(head_units, activation='relu'),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def get_callbacks(prefix):
    return [
        EarlyStopping(monitor='val_loss', patience=PATIENCE_ES, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=PATIENCE_RLRP,
                          min_lr=MIN_LR, verbose=1),
        ModelCheckpoint(f"/kaggle/working/{prefix}.h5", monitor='val_accuracy', save_best_only=True, verbose=1)
    ]

# =========================
# Two-stage training
# =========================
def two_stage_train(model_name, base_fn,
                    stage1_epochs=STAGE1_EPOCHS, stage2_epochs=STAGE2_EPOCHS,
                    unfreeze_fraction=UNFREEZE_FRACTION,
                    lr_stage1=BASE_LR, lr_stage2=1e-5):
    print(f"\n=== {model_name}: Stage 1 (feature extraction) ===")
    base, src = load_base_with_fallback(model_name, base_fn, IMG_SIZE+(3,))
    base.trainable = False
    model = build_classifier(base, lr=lr_stage1)
    cb1 = get_callbacks(f"{model_name}_stage1")
    hist1 = model.fit(train_gen, validation_data=val_gen, epochs=stage1_epochs, callbacks=cb1, verbose=1)

    print(f"=== {model_name}: Stage 2 (fine-tune top {int(unfreeze_fraction*100)}%) ===")
    total_layers = len(base.layers)
    unfreeze_at = int(total_layers * (1 - unfreeze_fraction))
    for i, layer in enumerate(base.layers):
        layer.trainable = True if i >= unfreeze_at else False

    model.compile(optimizer=Adam(learning_rate=lr_stage2), loss='categorical_crossentropy', metrics=['accuracy'])
    cb2 = get_callbacks(f"{model_name}_stage2")
    hist2 = model.fit(train_gen, validation_data=val_gen, epochs=stage2_epochs, callbacks=cb2, verbose=1)

    return model, hist1, hist2, src

# =========================
# Evaluation on TEST
# =========================
def evaluate_on_test(model, model_name, class_names):
    test_gen.reset()
    y_probs = model.predict(test_gen, verbose=1)
    y_pred = np.argmax(y_probs, axis=1)
    y_true = test_gen.classes

    test_acc = accuracy_score(y_true, y_pred)

    labels_present = sorted(list(set(y_true) | set(y_pred)))
    target_names = [class_names[i] for i in labels_present]
    print("\n=== Classification Report (TEST) ===")
    print(classification_report(y_true, y_pred, labels=labels_present, target_names=target_names, zero_division=0))

    cm = confusion_matrix(y_true, y_pred, labels=range(len(class_names)))
    plt.figure(figsize=(9,7))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f"{model_name} — Confusion Matrix (TEST)")
    plt.ylabel('True'); plt.xlabel('Predicted'); plt.tight_layout(); plt.show()

    y_true_bin = label_binarize(y_true, classes=range(len(class_names)))
    try:
        auc_macro = roc_auc_score(y_true_bin, y_probs, average='macro', multi_class='ovr')
        auc_micro = roc_auc_score(y_true_bin, y_probs, average='micro', multi_class='ovr')
    except Exception:
        auc_macro, auc_micro = np.nan, np.nan

    # ROC plots (subset for readability)
    K = min(10, len(class_names))
    fpr_micro, tpr_micro, _ = roc_curve(y_true_bin.ravel(), y_probs.ravel())
    plt.figure(figsize=(8,6))
    plt.plot(fpr_micro, tpr_micro, linestyle=':', label=f"micro (AUC={auc_micro:.3f})")
    for i in range(K):
        try:
            fpr_i, tpr_i, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
            auc_i = roc_auc_score(y_true_bin[:, i], y_probs[:, i])
            plt.plot(fpr_i, tpr_i, lw=1, label=f"{class_names[i]} (AUC={auc_i:.3f})")
        except Exception:
            pass
    plt.plot([0,1],[0,1],'k--')
    plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
    plt.title(f"{model_name} — ROC (TEST, first {K} classes) | macro AUC={auc_macro:.3f}")
    plt.legend(fontsize='x-small', bbox_to_anchor=(1.05,1))
    plt.tight_layout(); plt.show()

    # per-class accuracy
    class_acc = []
    for i in range(len(class_names)):
        idx = np.where(y_true == i)[0]
        if len(idx) == 0:
            class_acc.append(np.nan)
        else:
            class_acc.append(accuracy_score(y_true[idx], y_pred[idx]))

    return {
        "y_true": y_true,
        "y_pred": y_pred,
        "y_probs": y_probs,
        "overall_acc": test_acc,
        "auc_macro": auc_macro,
        "auc_micro": auc_micro,
        "confusion_matrix": cm,
        "class_accuracy": class_acc
    }

# =========================
# Train all three + TEST eval
# =========================
models_to_run = [
    ("VGG16", VGG16),
    ("ResNet50", ResNet50),
    ("EfficientNetB0", EfficientNetB0),
]

trained_models = {}
reports = {}
train_times_sec = {}
test_times_sec = {}
weight_sources = {}

for name, fn in models_to_run:
    print("\n" + "="*70)
    print(f"Training: {name}")
    t0 = time.time()
    model, h1, h2, src = two_stage_train(name, fn)
    t1 = time.time()
    train_times_sec[name] = t1 - t0
    weight_sources[name] = src
    trained_models[name] = model

    print("Evaluating on TEST set...")
    t0 = time.time()
    rep = evaluate_on_test(model, name, class_names)
    t1 = time.time()
    test_times_sec[name] = t1 - t0
    reports[name] = rep

    print(f"{name} — TEST Acc: {rep['overall_acc']:.4f} | AUC(macro): {rep['auc_macro']:.4f} | AUC(micro): {rep['auc_micro']:.4f} | weights={src}")

# =========================
# Summary tables + CSVs
# =========================
rows = []
for name, r in reports.items():
    rows.append({
        "Model": name,
        "Weights Source": weight_sources.get(name, "unknown"),
        "Test Accuracy": r["overall_acc"],
        "Test AUC (macro OVR)": r["auc_macro"],
        "Test AUC (micro)": r["auc_micro"],
        "Train Time (s)": train_times_sec.get(name, np.nan),
        "Test Eval Time (s)": test_times_sec.get(name, np.nan),
    })
summary_df = pd.DataFrame(rows).sort_values("Test Accuracy", ascending=False)
display(summary_df)

per_class_rows = []
for name, r in reports.items():
    y_true = r["y_true"]; y_pred = r["y_pred"]
    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, labels=list(range(len(class_names))), zero_division=0
    )
    for i, cls in enumerate(class_names):
        per_class_rows.append({
            "Model": name,
            "Class": cls,
            "Precision": precision[i],
            "Recall": recall[i],
            "F1": f1[i],
            "Support": support[i],
            "Class Accuracy": r["class_accuracy"][i]
        })
per_class_df = pd.DataFrame(per_class_rows)

summary_path  = "/kaggle/working/task2_tomato_TEST_summary_metrics.csv"
perclass_path = "/kaggle/working/task2_tomato_TEST_per_class_metrics.csv"
summary_df.to_csv(summary_path, index=False)
per_class_df.to_csv(perclass_path, index=False)
print("Saved:", summary_path)
print("Saved:", perclass_path)

# =========================
# Paired t-tests on TEST
# =========================
names = list(reports.keys())
correct = {m: (reports[m]["y_pred"] == reports[m]["y_true"]).astype(int) for m in names}

ttest_rows = []
for i in range(len(names)):
    for j in range(i+1, len(names)):
        a = correct[names[i]]
        b = correct[names[j]]
        tstat, pval = ttest_rel(a, b)
        ttest_rows.append({
            "Model A": names[i],
            "Model B": names[j],
            "t-stat": float(tstat),
            "p-value": float(pval)
        })
ttest_df = pd.DataFrame(ttest_rows)
display(ttest_df)

ttest_path = "/kaggle/working/task2_tomato_TEST_paired_ttest.csv"
ttest_df.to_csv(ttest_path, index=False)
print("Saved:", ttest_path)
# Out:
# 2025-11-12 19:51:27.859468: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762977088.077403      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762977088.126502      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow: 2.18.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# base_dir: /kaggle/input/plantdisease/PlantVillage | work_root: /kaggle/working/Tomato_Split
# Tomato_Bacterial_spot: total=2127 -> train=1277, val=319, test=531
# Tomato_Early_blight: total=1000 -> train=600, val=150, test=250
# Tomato_Late_blight: total=1909 -> train=1146, val=286, test=477
# Tomato_Leaf_Mold: total=952 -> train=572, val=142, test=238
# Tomato_Septoria_leaf_spot: total=1771 -> train=1064, val=265, test=442
# Tomato_Spider_mites_Two_spotted_spider_mite: total=1676 -> train=1006, val=251, test=419
# Tomato__Target_Spot: total=1404 -> train=843, val=210, test=351
# Tomato__Tomato_YellowLeaf__Curl_Virus: total=3208 -> train=1925, val=481, test=802
# Tomato__Tomato_mosaic_virus: total=373 -> train=224, val=56, test=93
# Tomato_healthy: total=1591 -> train=956, val=238, test=397
# train: 9613 images
# val: 2398 images
# test: 4000 images
# Found 9613 images belonging to 10 classes.
# Found 2398 images belonging to 10 classes.
# Found 4000 images belonging to 10 classes.
# Classes detected: ['Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']
# Counts -> Train: 9613 Val: 2398 Test: 4000
#
# ======================================================================
# Training: VGG16
#
# === VGG16: Stage 1 (feature extraction) ===
# I0000 00:00:1762977186.634301      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1762977186.634986      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [VGG16] Using ImageNet weights (download/cache).
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/35
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762977192.054964      84 service.cc:148] XLA service 0x7fd58800d710 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762977192.055778      84 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1762977192.055803      84 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1762977192.463268      84 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/301 ━━━━━━━━━━━━━━━━━━━━ 1:13:31 15s/step - accuracy: 0.0938 - loss: 2.6063
# I0000 00:00:1762977204.010607      84 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.2049 - loss: 2.2452
# Epoch 1: val_accuracy improved from -inf to 0.49917, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 157s 474ms/step - accuracy: 0.2051 - loss: 2.2446 - val_accuracy: 0.4992 - val_loss: 1.7096 - learning_rate: 3.0000e-04
# Epoch 2/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.4086 - loss: 1.7712
# Epoch 2: val_accuracy improved from 0.49917 to 0.52043, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 127s 423ms/step - accuracy: 0.4087 - loss: 1.7710 - val_accuracy: 0.5204 - val_loss: 1.4471 - learning_rate: 3.0000e-04
# Epoch 3/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.4795 - loss: 1.5357
# Epoch 3: val_accuracy improved from 0.52043 to 0.60842, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 427ms/step - accuracy: 0.4796 - loss: 1.5356 - val_accuracy: 0.6084 - val_loss: 1.2464 - learning_rate: 3.0000e-04
# Epoch 4/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.5271 - loss: 1.4159
# Epoch 4: val_accuracy improved from 0.60842 to 0.61134, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 136s 450ms/step - accuracy: 0.5271 - loss: 1.4158 - val_accuracy: 0.6113 - val_loss: 1.1704 - learning_rate: 3.0000e-04
# Epoch 5/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.5489 - loss: 1.3296
# Epoch 5: val_accuracy improved from 0.61134 to 0.63636, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 139s 460ms/step - accuracy: 0.5489 - loss: 1.3296 - val_accuracy: 0.6364 - val_loss: 1.1009 - learning_rate: 3.0000e-04
# Epoch 6/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.5673 - loss: 1.2798
# Epoch 6: val_accuracy improved from 0.63636 to 0.68098, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 134s 444ms/step - accuracy: 0.5673 - loss: 1.2798 - val_accuracy: 0.6810 - val_loss: 1.0113 - learning_rate: 3.0000e-04
# Epoch 7/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.5940 - loss: 1.2135
# Epoch 7: val_accuracy improved from 0.68098 to 0.68766, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 134s 446ms/step - accuracy: 0.5940 - loss: 1.2135 - val_accuracy: 0.6877 - val_loss: 0.9855 - learning_rate: 3.0000e-04
# Epoch 8/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.6068 - loss: 1.1694
# Epoch 8: val_accuracy improved from 0.68766 to 0.70809, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 135s 448ms/step - accuracy: 0.6068 - loss: 1.1694 - val_accuracy: 0.7081 - val_loss: 0.9291 - learning_rate: 3.0000e-04
# Epoch 9/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.6103 - loss: 1.1511
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 9: val_accuracy did not improve from 0.70809
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 428ms/step - accuracy: 0.6103 - loss: 1.1511 - val_accuracy: 0.6835 - val_loss: 0.9477 - learning_rate: 3.0000e-04
# Epoch 10/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.6141 - loss: 1.1456
# Epoch 10: val_accuracy improved from 0.70809 to 0.72686, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 427ms/step - accuracy: 0.6141 - loss: 1.1455 - val_accuracy: 0.7269 - val_loss: 0.8811 - learning_rate: 1.5000e-04
# Epoch 11/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6244 - loss: 1.1132
# Epoch 11: val_accuracy did not improve from 0.72686
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 424ms/step - accuracy: 0.6244 - loss: 1.1132 - val_accuracy: 0.7227 - val_loss: 0.8752 - learning_rate: 1.5000e-04
# Epoch 12/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.6319 - loss: 1.0906
# Epoch 12: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 12: val_accuracy did not improve from 0.72686
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 426ms/step - accuracy: 0.6319 - loss: 1.0906 - val_accuracy: 0.7219 - val_loss: 0.8787 - learning_rate: 1.5000e-04
# Epoch 13/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6395 - loss: 1.0824
# Epoch 13: val_accuracy did not improve from 0.72686
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 427ms/step - accuracy: 0.6395 - loss: 1.0824 - val_accuracy: 0.7219 - val_loss: 0.8579 - learning_rate: 7.5000e-05
# Epoch 14/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6362 - loss: 1.0846
# Epoch 14: val_accuracy improved from 0.72686 to 0.72977, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 426ms/step - accuracy: 0.6362 - loss: 1.0846 - val_accuracy: 0.7298 - val_loss: 0.8548 - learning_rate: 7.5000e-05
# Epoch 15/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6271 - loss: 1.0843
# Epoch 15: val_accuracy improved from 0.72977 to 0.73186, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 126s 418ms/step - accuracy: 0.6272 - loss: 1.0843 - val_accuracy: 0.7319 - val_loss: 0.8501 - learning_rate: 7.5000e-05
# Epoch 16/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6288 - loss: 1.0864
# Epoch 16: val_accuracy did not improve from 0.73186
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 425ms/step - accuracy: 0.6288 - loss: 1.0864 - val_accuracy: 0.7306 - val_loss: 0.8458 - learning_rate: 7.5000e-05
# Epoch 17/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.6326 - loss: 1.0963
# Epoch 17: val_accuracy improved from 0.73186 to 0.73853, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 127s 422ms/step - accuracy: 0.6326 - loss: 1.0962 - val_accuracy: 0.7385 - val_loss: 0.8410 - learning_rate: 7.5000e-05
# Epoch 18/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.6309 - loss: 1.0781
# Epoch 18: val_accuracy did not improve from 0.73853
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 127s 421ms/step - accuracy: 0.6309 - loss: 1.0781 - val_accuracy: 0.7377 - val_loss: 0.8363 - learning_rate: 7.5000e-05
# Epoch 19/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.6376 - loss: 1.0724
# Epoch 19: val_accuracy did not improve from 0.73853
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 130s 431ms/step - accuracy: 0.6376 - loss: 1.0724 - val_accuracy: 0.7364 - val_loss: 0.8220 - learning_rate: 7.5000e-05
# Epoch 20/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.6402 - loss: 1.0634
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 20: val_accuracy did not improve from 0.73853
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 426ms/step - accuracy: 0.6402 - loss: 1.0634 - val_accuracy: 0.7327 - val_loss: 0.8277 - learning_rate: 7.5000e-05
# Epoch 21/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.6398 - loss: 1.0607
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
#
# Epoch 21: val_accuracy did not improve from 0.73853
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 428ms/step - accuracy: 0.6398 - loss: 1.0607 - val_accuracy: 0.7381 - val_loss: 0.8220 - learning_rate: 3.7500e-05
# Epoch 22/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6395 - loss: 1.0656
# Epoch 22: val_accuracy improved from 0.73853 to 0.74103, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 427ms/step - accuracy: 0.6395 - loss: 1.0655 - val_accuracy: 0.7410 - val_loss: 0.8169 - learning_rate: 1.8750e-05
# Epoch 23/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6364 - loss: 1.0563
# Epoch 23: val_accuracy did not improve from 0.74103
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 425ms/step - accuracy: 0.6364 - loss: 1.0562 - val_accuracy: 0.7410 - val_loss: 0.8118 - learning_rate: 1.8750e-05
# Epoch 24/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6537 - loss: 1.0303
# Epoch 24: val_accuracy improved from 0.74103 to 0.74479, saving model to /kaggle/working/VGG16_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 424ms/step - accuracy: 0.6537 - loss: 1.0303 - val_accuracy: 0.7448 - val_loss: 0.8094 - learning_rate: 1.8750e-05
# Epoch 25/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6555 - loss: 1.0268
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
#
# Epoch 25: val_accuracy did not improve from 0.74479
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 425ms/step - accuracy: 0.6555 - loss: 1.0268 - val_accuracy: 0.7381 - val_loss: 0.8176 - learning_rate: 1.8750e-05
# Epoch 26/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6426 - loss: 1.0515
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
#
# Epoch 26: val_accuracy did not improve from 0.74479
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 132s 439ms/step - accuracy: 0.6426 - loss: 1.0515 - val_accuracy: 0.7415 - val_loss: 0.8139 - learning_rate: 9.3750e-06
# Epoch 27/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.6463 - loss: 1.0381
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.3437501113221515e-06.
#
# Epoch 27: val_accuracy did not improve from 0.74479
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 424ms/step - accuracy: 0.6463 - loss: 1.0381 - val_accuracy: 0.7431 - val_loss: 0.8117 - learning_rate: 4.6875e-06
# === VGG16: Stage 2 (fine-tune top 25%) ===
# Epoch 1/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.6818 - loss: 0.9366
# Epoch 1: val_accuracy improved from -inf to 0.82485, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 140s 441ms/step - accuracy: 0.6819 - loss: 0.9362 - val_accuracy: 0.8249 - val_loss: 0.5323 - learning_rate: 1.0000e-05
# Epoch 2/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.7843 - loss: 0.6201
# Epoch 2: val_accuracy improved from 0.82485 to 0.87239, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 133s 442ms/step - accuracy: 0.7843 - loss: 0.6200 - val_accuracy: 0.8724 - val_loss: 0.4085 - learning_rate: 1.0000e-05
# Epoch 3/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8204 - loss: 0.5218
# Epoch 3: val_accuracy improved from 0.87239 to 0.87698, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 137s 454ms/step - accuracy: 0.8204 - loss: 0.5218 - val_accuracy: 0.8770 - val_loss: 0.3864 - learning_rate: 1.0000e-05
# Epoch 4/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8459 - loss: 0.4551
# Epoch 4: val_accuracy improved from 0.87698 to 0.89450, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 138s 459ms/step - accuracy: 0.8459 - loss: 0.4551 - val_accuracy: 0.8945 - val_loss: 0.3347 - learning_rate: 1.0000e-05
# Epoch 5/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8616 - loss: 0.4008
# Epoch 5: val_accuracy improved from 0.89450 to 0.89908, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 137s 456ms/step - accuracy: 0.8616 - loss: 0.4008 - val_accuracy: 0.8991 - val_loss: 0.3218 - learning_rate: 1.0000e-05
# Epoch 6/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8775 - loss: 0.3572
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 6: val_accuracy improved from 0.89908 to 0.89992, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 139s 462ms/step - accuracy: 0.8775 - loss: 0.3573 - val_accuracy: 0.8999 - val_loss: 0.3301 - learning_rate: 1.0000e-05
# Epoch 7/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8816 - loss: 0.3359
# Epoch 7: val_accuracy improved from 0.89992 to 0.92160, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 133s 440ms/step - accuracy: 0.8816 - loss: 0.3358 - val_accuracy: 0.9216 - val_loss: 0.2472 - learning_rate: 5.0000e-06
# Epoch 8/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8889 - loss: 0.3132
# Epoch 8: val_accuracy improved from 0.92160 to 0.92410, saving model to /kaggle/working/VGG16_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 128s 425ms/step - accuracy: 0.8889 - loss: 0.3131 - val_accuracy: 0.9241 - val_loss: 0.2402 - learning_rate: 5.0000e-06
# Epoch 9/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9055 - loss: 0.2816
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 9: val_accuracy did not improve from 0.92410
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 131s 434ms/step - accuracy: 0.9055 - loss: 0.2816 - val_accuracy: 0.9199 - val_loss: 0.2488 - learning_rate: 5.0000e-06
# Epoch 10/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9127 - loss: 0.2604
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 10: val_accuracy did not improve from 0.92410
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 132s 437ms/step - accuracy: 0.9127 - loss: 0.2604 - val_accuracy: 0.9204 - val_loss: 0.2487 - learning_rate: 2.5000e-06
# Epoch 11/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9075 - loss: 0.2692
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 11: val_accuracy did not improve from 0.92410
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 129s 427ms/step - accuracy: 0.9075 - loss: 0.2692 - val_accuracy: 0.9229 - val_loss: 0.2498 - learning_rate: 1.2500e-06
# Evaluating on TEST set...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step
#
# === Classification Report (TEST) ===
#                                              precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.93      0.97      0.95       531
#                         Tomato_Early_blight       0.91      0.65      0.76       250
#                          Tomato_Late_blight       0.94      0.94      0.94       477
#                            Tomato_Leaf_Mold       0.96      0.87      0.92       238
#                   Tomato_Septoria_leaf_spot       0.85      0.96      0.90       442
# Tomato_Spider_mites_Two_spotted_spider_mite       0.88      0.95      0.91       419
#                         Tomato__Target_Spot       0.84      0.85      0.85       351
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.99      0.97      0.98       802
#                 Tomato__Tomato_mosaic_virus       0.96      0.91      0.93        93
#                              Tomato_healthy       0.97      0.97      0.97       397
#
#                                    accuracy                           0.93      4000
#                                   macro avg       0.92      0.91      0.91      4000
#                                weighted avg       0.93      0.93      0.93      4000
# VGG16 — TEST Acc: 0.9267 | AUC(macro): 0.9959 | AUC(micro): 0.9969 | weights=imagenet
#
# ======================================================================
# Training: ResNet50
#
# === ResNet50: Stage 1 (feature extraction) ===
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [ResNet50] Using ImageNet weights (download/cache).
# Epoch 1/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.1509 - loss: 2.4062
# Epoch 1: val_accuracy improved from -inf to 0.24896, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 149s 441ms/step - accuracy: 0.1510 - loss: 2.4058 - val_accuracy: 0.2490 - val_loss: 2.1461 - learning_rate: 3.0000e-04
# Epoch 2/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.1974 - loss: 2.1803
# Epoch 2: val_accuracy did not improve from 0.24896
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 119s 394ms/step - accuracy: 0.1974 - loss: 2.1803 - val_accuracy: 0.2389 - val_loss: 2.0932 - learning_rate: 3.0000e-04
# Epoch 3/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2212 - loss: 2.1369
# Epoch 3: val_accuracy improved from 0.24896 to 0.26355, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 401ms/step - accuracy: 0.2212 - loss: 2.1368 - val_accuracy: 0.2636 - val_loss: 2.0470 - learning_rate: 3.0000e-04
# Epoch 4/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.2220 - loss: 2.1205
# Epoch 4: val_accuracy did not improve from 0.26355
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 119s 395ms/step - accuracy: 0.2220 - loss: 2.1204 - val_accuracy: 0.2419 - val_loss: 2.0127 - learning_rate: 3.0000e-04
# Epoch 5/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2357 - loss: 2.0912
# Epoch 5: val_accuracy did not improve from 0.26355
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.2357 - loss: 2.0912 - val_accuracy: 0.2544 - val_loss: 1.9989 - learning_rate: 3.0000e-04
# Epoch 6/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2387 - loss: 2.0676
# Epoch 6: val_accuracy improved from 0.26355 to 0.30734, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 402ms/step - accuracy: 0.2387 - loss: 2.0676 - val_accuracy: 0.3073 - val_loss: 1.9831 - learning_rate: 3.0000e-04
# Epoch 7/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2310 - loss: 2.0701
# Epoch 7: val_accuracy did not improve from 0.30734
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 399ms/step - accuracy: 0.2311 - loss: 2.0700 - val_accuracy: 0.2898 - val_loss: 1.9702 - learning_rate: 3.0000e-04
# Epoch 8/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2533 - loss: 2.0397
# Epoch 8: val_accuracy improved from 0.30734 to 0.31693, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 400ms/step - accuracy: 0.2533 - loss: 2.0397 - val_accuracy: 0.3169 - val_loss: 1.9417 - learning_rate: 3.0000e-04
# Epoch 9/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2521 - loss: 2.0256
# Epoch 9: val_accuracy improved from 0.31693 to 0.32611, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 122s 405ms/step - accuracy: 0.2522 - loss: 2.0256 - val_accuracy: 0.3261 - val_loss: 1.9350 - learning_rate: 3.0000e-04
# Epoch 10/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2664 - loss: 2.0086
# Epoch 10: val_accuracy improved from 0.32611 to 0.33862, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 400ms/step - accuracy: 0.2664 - loss: 2.0087 - val_accuracy: 0.3386 - val_loss: 1.9198 - learning_rate: 3.0000e-04
# Epoch 11/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2688 - loss: 1.9990
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 11: val_accuracy did not improve from 0.33862
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.2688 - loss: 1.9990 - val_accuracy: 0.2702 - val_loss: 1.9268 - learning_rate: 3.0000e-04
# Epoch 12/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.2640 - loss: 1.9921
# Epoch 12: val_accuracy improved from 0.33862 to 0.36322, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 122s 404ms/step - accuracy: 0.2641 - loss: 1.9921 - val_accuracy: 0.3632 - val_loss: 1.9054 - learning_rate: 1.5000e-04
# Epoch 13/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2801 - loss: 1.9851
# Epoch 13: val_accuracy did not improve from 0.36322
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.2801 - loss: 1.9851 - val_accuracy: 0.3545 - val_loss: 1.8754 - learning_rate: 1.5000e-04
# Epoch 14/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.2806 - loss: 1.9815
# Epoch 14: val_accuracy did not improve from 0.36322
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 119s 396ms/step - accuracy: 0.2807 - loss: 1.9814 - val_accuracy: 0.3632 - val_loss: 1.8682 - learning_rate: 1.5000e-04
# Epoch 15/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2945 - loss: 1.9634
# Epoch 15: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 15: val_accuracy did not improve from 0.36322
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 402ms/step - accuracy: 0.2945 - loss: 1.9634 - val_accuracy: 0.3620 - val_loss: 1.8893 - learning_rate: 1.5000e-04
# Epoch 16/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.2693 - loss: 1.9888
# Epoch 16: val_accuracy improved from 0.36322 to 0.37573, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.2693 - loss: 1.9887 - val_accuracy: 0.3757 - val_loss: 1.8673 - learning_rate: 7.5000e-05
# Epoch 17/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.2880 - loss: 1.9593
# Epoch 17: val_accuracy did not improve from 0.37573
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 401ms/step - accuracy: 0.2880 - loss: 1.9593 - val_accuracy: 0.3753 - val_loss: 1.8609 - learning_rate: 7.5000e-05
# Epoch 18/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2896 - loss: 1.9540
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 18: val_accuracy did not improve from 0.37573
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.2897 - loss: 1.9540 - val_accuracy: 0.3749 - val_loss: 1.8613 - learning_rate: 7.5000e-05
# Epoch 19/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.3023 - loss: 1.9494
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
#
# Epoch 19: val_accuracy improved from 0.37573 to 0.37740, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 397ms/step - accuracy: 0.3023 - loss: 1.9495 - val_accuracy: 0.3774 - val_loss: 1.8659 - learning_rate: 3.7500e-05
# Epoch 20/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.3032 - loss: 1.9425
# Epoch 20: val_accuracy improved from 0.37740 to 0.38073, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 401ms/step - accuracy: 0.3032 - loss: 1.9425 - val_accuracy: 0.3807 - val_loss: 1.8605 - learning_rate: 1.8750e-05
# Epoch 21/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2864 - loss: 1.9617
# Epoch 21: val_accuracy improved from 0.38073 to 0.38365, saving model to /kaggle/working/ResNet50_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 119s 394ms/step - accuracy: 0.2864 - loss: 1.9617 - val_accuracy: 0.3837 - val_loss: 1.8459 - learning_rate: 1.8750e-05
# Epoch 22/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2926 - loss: 1.9574
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
#
# Epoch 22: val_accuracy did not improve from 0.38365
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 118s 392ms/step - accuracy: 0.2926 - loss: 1.9574 - val_accuracy: 0.3803 - val_loss: 1.8527 - learning_rate: 1.8750e-05
# Epoch 23/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2971 - loss: 1.9475
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
#
# Epoch 23: val_accuracy did not improve from 0.38365
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 122s 404ms/step - accuracy: 0.2971 - loss: 1.9475 - val_accuracy: 0.3820 - val_loss: 1.8469 - learning_rate: 9.3750e-06
# Epoch 24/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.2882 - loss: 1.9459
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.3437501113221515e-06.
#
# Epoch 24: val_accuracy did not improve from 0.38365
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 118s 391ms/step - accuracy: 0.2882 - loss: 1.9459 - val_accuracy: 0.3824 - val_loss: 1.8515 - learning_rate: 4.6875e-06
# === ResNet50: Stage 2 (fine-tune top 25%) ===
# Epoch 1/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.2667 - loss: 3.9970
# Epoch 1: val_accuracy improved from -inf to 0.16180, saving model to /kaggle/working/ResNet50_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 165s 451ms/step - accuracy: 0.2669 - loss: 3.9916 - val_accuracy: 0.1618 - val_loss: 2.4731 - learning_rate: 1.0000e-05
# Epoch 2/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.4540 - loss: 1.5899
# Epoch 2: val_accuracy improved from 0.16180 to 0.40951, saving model to /kaggle/working/ResNet50_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 400ms/step - accuracy: 0.4541 - loss: 1.5897 - val_accuracy: 0.4095 - val_loss: 1.8025 - learning_rate: 1.0000e-05
# Epoch 3/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.4981 - loss: 1.4734
# Epoch 3: val_accuracy improved from 0.40951 to 0.54671, saving model to /kaggle/working/ResNet50_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 122s 405ms/step - accuracy: 0.4981 - loss: 1.4733 - val_accuracy: 0.5467 - val_loss: 1.2563 - learning_rate: 1.0000e-05
# Epoch 4/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.5361 - loss: 1.3555
# Epoch 4: val_accuracy improved from 0.54671 to 0.57756, saving model to /kaggle/working/ResNet50_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 122s 404ms/step - accuracy: 0.5361 - loss: 1.3555 - val_accuracy: 0.5776 - val_loss: 1.2079 - learning_rate: 1.0000e-05
# Epoch 5/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.5498 - loss: 1.3184
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 5: val_accuracy did not improve from 0.57756
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.5498 - loss: 1.3184 - val_accuracy: 0.5738 - val_loss: 1.2541 - learning_rate: 1.0000e-05
# Epoch 6/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.5779 - loss: 1.2268
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 6: val_accuracy did not improve from 0.57756
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 123s 409ms/step - accuracy: 0.5779 - loss: 1.2268 - val_accuracy: 0.4762 - val_loss: 1.6783 - learning_rate: 5.0000e-06
# Epoch 7/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.5968 - loss: 1.1844
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 7: val_accuracy did not improve from 0.57756
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 122s 405ms/step - accuracy: 0.5968 - loss: 1.1843 - val_accuracy: 0.5309 - val_loss: 1.4102 - learning_rate: 2.5000e-06
# Evaluating on TEST set...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 15s 81ms/step
#
# === Classification Report (TEST) ===
#                                              precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.64      0.89      0.74       531
#                         Tomato_Early_blight       0.80      0.02      0.03       250
#                          Tomato_Late_blight       0.56      0.56      0.56       477
#                            Tomato_Leaf_Mold       0.25      0.01      0.02       238
#                   Tomato_Septoria_leaf_spot       0.48      0.41      0.44       442
# Tomato_Spider_mites_Two_spotted_spider_mite       0.52      0.67      0.58       419
#                         Tomato__Target_Spot       0.31      0.38      0.34       351
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.90      0.78      0.83       802
#                 Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        93
#                              Tomato_healthy       0.53      0.97      0.69       397
#
#                                    accuracy                           0.59      4000
#                                   macro avg       0.50      0.47      0.42      4000
#                                weighted avg       0.58      0.59      0.54      4000
# ResNet50 — TEST Acc: 0.5880 | AUC(macro): 0.9091 | AUC(micro): 0.9221 | weights=imagenet
#
# ======================================================================
# Training: EfficientNetB0
#
# === EfficientNetB0: Stage 1 (feature extraction) ===
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [EfficientNetB0] Using ImageNet weights (download/cache).
# Epoch 1/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.1687 - loss: 2.2484
# Epoch 1: val_accuracy improved from -inf to 0.20058, saving model to /kaggle/working/EfficientNetB0_stage1.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 160s 448ms/step - accuracy: 0.1688 - loss: 2.2483 - val_accuracy: 0.2006 - val_loss: 2.2009 - learning_rate: 3.0000e-04
# Epoch 2/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.1956 - loss: 2.2083
# Epoch 2: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 114s 380ms/step - accuracy: 0.1956 - loss: 2.2083 - val_accuracy: 0.2006 - val_loss: 2.1957 - learning_rate: 3.0000e-04
# Epoch 3/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.1853 - loss: 2.2128
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 3: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 113s 376ms/step - accuracy: 0.1853 - loss: 2.2128 - val_accuracy: 0.2006 - val_loss: 2.1963 - learning_rate: 3.0000e-04
# Epoch 4/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.1993 - loss: 2.2053
# Epoch 4: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 4: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 113s 376ms/step - accuracy: 0.1993 - loss: 2.2054 - val_accuracy: 0.2006 - val_loss: 2.1970 - learning_rate: 1.5000e-04
# Epoch 5/35
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2010 - loss: 2.2102
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 5: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 115s 381ms/step - accuracy: 0.2010 - loss: 2.2102 - val_accuracy: 0.2006 - val_loss: 2.1962 - learning_rate: 7.5000e-05
# === EfficientNetB0: Stage 2 (fine-tune top 25%) ===
# Epoch 1/40
# E0000 00:00:1762986692.861757      84 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1762986693.003118      84 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.1187 - loss: 2.4409
# Epoch 1: val_accuracy improved from -inf to 0.20058, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 177s 457ms/step - accuracy: 0.1188 - loss: 2.4405 - val_accuracy: 0.2006 - val_loss: 2.2119 - learning_rate: 1.0000e-05
# Epoch 2/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.1828 - loss: 2.2307
# Epoch 2: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 115s 380ms/step - accuracy: 0.1828 - loss: 2.2307 - val_accuracy: 0.2006 - val_loss: 2.2011 - learning_rate: 1.0000e-05
# Epoch 3/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.1891 - loss: 2.2165
# Epoch 3: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 117s 388ms/step - accuracy: 0.1891 - loss: 2.2165 - val_accuracy: 0.2006 - val_loss: 2.1785 - learning_rate: 1.0000e-05
# Epoch 4/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2050 - loss: 2.1826
# Epoch 4: val_accuracy did not improve from 0.20058
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 115s 383ms/step - accuracy: 0.2050 - loss: 2.1826 - val_accuracy: 0.2006 - val_loss: 2.1576 - learning_rate: 1.0000e-05
# Epoch 5/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2091 - loss: 2.1750
# Epoch 5: val_accuracy improved from 0.20058 to 0.20183, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 116s 384ms/step - accuracy: 0.2091 - loss: 2.1750 - val_accuracy: 0.2018 - val_loss: 2.1366 - learning_rate: 1.0000e-05
# Epoch 6/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2064 - loss: 2.1719
# Epoch 6: val_accuracy improved from 0.20183 to 0.22936, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 117s 390ms/step - accuracy: 0.2064 - loss: 2.1719 - val_accuracy: 0.2294 - val_loss: 2.0880 - learning_rate: 1.0000e-05
# Epoch 7/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.2127 - loss: 2.1497
# Epoch 7: val_accuracy improved from 0.22936 to 0.26981, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 116s 384ms/step - accuracy: 0.2127 - loss: 2.1497 - val_accuracy: 0.2698 - val_loss: 2.0759 - learning_rate: 1.0000e-05
# Epoch 8/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2116 - loss: 2.1505
# Epoch 8: val_accuracy improved from 0.26981 to 0.30359, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 116s 386ms/step - accuracy: 0.2116 - loss: 2.1505 - val_accuracy: 0.3036 - val_loss: 2.0531 - learning_rate: 1.0000e-05
# Epoch 9/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.2245 - loss: 2.1356
# Epoch 9: val_accuracy did not improve from 0.30359
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 398ms/step - accuracy: 0.2244 - loss: 2.1356 - val_accuracy: 0.2832 - val_loss: 2.0468 - learning_rate: 1.0000e-05
# Epoch 10/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2258 - loss: 2.1223
# Epoch 10: val_accuracy did not improve from 0.30359
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 119s 395ms/step - accuracy: 0.2258 - loss: 2.1223 - val_accuracy: 0.2994 - val_loss: 2.0225 - learning_rate: 1.0000e-05
# Epoch 11/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.2344 - loss: 2.1120
# Epoch 11: val_accuracy did not improve from 0.30359
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 121s 403ms/step - accuracy: 0.2343 - loss: 2.1120 - val_accuracy: 0.3023 - val_loss: 2.0076 - learning_rate: 1.0000e-05
# Epoch 12/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.2309 - loss: 2.1108
# Epoch 12: val_accuracy did not improve from 0.30359
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 123s 408ms/step - accuracy: 0.2309 - loss: 2.1108 - val_accuracy: 0.2961 - val_loss: 1.9926 - learning_rate: 1.0000e-05
# Epoch 13/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.2336 - loss: 2.1078
# Epoch 13: val_accuracy improved from 0.30359 to 0.31276, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 120s 397ms/step - accuracy: 0.2336 - loss: 2.1078 - val_accuracy: 0.3128 - val_loss: 1.9908 - learning_rate: 1.0000e-05
# Epoch 14/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2422 - loss: 2.0909
# Epoch 14: val_accuracy improved from 0.31276 to 0.31943, saving model to /kaggle/working/EfficientNetB0_stage2.h5
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 117s 389ms/step - accuracy: 0.2422 - loss: 2.0909 - val_accuracy: 0.3194 - val_loss: 1.9882 - learning_rate: 1.0000e-05
# Epoch 15/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2536 - loss: 2.0786
# Epoch 15: val_accuracy did not improve from 0.31943
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 116s 384ms/step - accuracy: 0.2536 - loss: 2.0786 - val_accuracy: 0.2857 - val_loss: 1.9797 - learning_rate: 1.0000e-05
# Epoch 16/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.2567 - loss: 2.0632
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 16: val_accuracy did not improve from 0.31943
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 117s 390ms/step - accuracy: 0.2567 - loss: 2.0632 - val_accuracy: 0.2731 - val_loss: 2.0325 - learning_rate: 1.0000e-05
# Epoch 17/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.2625 - loss: 2.0413
# Epoch 17: val_accuracy did not improve from 0.31943
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 117s 389ms/step - accuracy: 0.2625 - loss: 2.0413 - val_accuracy: 0.2877 - val_loss: 1.9716 - learning_rate: 5.0000e-06
# Epoch 18/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.2655 - loss: 2.0399
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 18: val_accuracy did not improve from 0.31943
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 116s 385ms/step - accuracy: 0.2654 - loss: 2.0399 - val_accuracy: 0.2802 - val_loss: 1.9910 - learning_rate: 5.0000e-06
# Epoch 19/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.2565 - loss: 2.0413
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 19: val_accuracy did not improve from 0.31943
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 113s 376ms/step - accuracy: 0.2565 - loss: 2.0413 - val_accuracy: 0.2852 - val_loss: 1.9783 - learning_rate: 2.5000e-06
# Epoch 20/40
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.2596 - loss: 2.0490
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 20: val_accuracy did not improve from 0.31943
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 117s 389ms/step - accuracy: 0.2596 - loss: 2.0490 - val_accuracy: 0.2798 - val_loss: 1.9818 - learning_rate: 1.2500e-06
# Evaluating on TEST set...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 14s 47ms/step
#
# === Classification Report (TEST) ===
#                                              precision    recall  f1-score   support
#
#                       Tomato_Bacterial_spot       0.00      0.00      0.00       531
#                         Tomato_Early_blight       0.00      0.00      0.00       250
#                          Tomato_Late_blight       0.00      0.00      0.00       477
#                            Tomato_Leaf_Mold       0.00      0.00      0.00       238
#                   Tomato_Septoria_leaf_spot       0.17      0.47      0.25       442
# Tomato_Spider_mites_Two_spotted_spider_mite       1.00      0.00      0.01       419
#                         Tomato__Target_Spot       0.00      0.00      0.00       351
#       Tomato__Tomato_YellowLeaf__Curl_Virus       0.29      0.89      0.44       802
#                 Tomato__Tomato_mosaic_virus       0.00      0.00      0.00        93
#                              Tomato_healthy       0.60      0.52      0.56       397
#
#                                    accuracy                           0.28      4000
#                                   macro avg       0.21      0.19      0.13      4000
#                                weighted avg       0.24      0.28      0.17      4000
# EfficientNetB0 — TEST Acc: 0.2825 | AUC(macro): 0.7404 | AUC(micro): 0.7414 | weights=imagenet
#             Model Weights Source  Test Accuracy  Test AUC (macro OVR)  \
# 0           VGG16       imagenet        0.92675              0.995938
# 1        ResNet50       imagenet        0.58800              0.909059
# 2  EfficientNetB0       imagenet        0.28250              0.740417
#
#    Test AUC (micro)  Train Time (s)  Test Eval Time (s)
# 0          0.996939     5010.184030           22.830803
# 1          0.922079     3809.249537           15.778241
# 2          0.741424     3023.964755           14.898023
# Saved: /kaggle/working/task2_tomato_TEST_summary_metrics.csv
# Saved: /kaggle/working/task2_tomato_TEST_per_class_metrics.csv
#     Model A         Model B     t-stat        p-value
# 0     VGG16        ResNet50  43.322844   0.000000e+00
# 1     VGG16  EfficientNetB0  82.109464   0.000000e+00
# 2  ResNet50  EfficientNetB0  34.010091  6.458173e-223
# Saved: /kaggle/working/task2_tomato_TEST_paired_ttest.csv
